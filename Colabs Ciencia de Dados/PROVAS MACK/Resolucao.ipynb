# %%
import pandas as pd

# %% [markdown]
# ## Questão 1

# %% [markdown]
# ## Questão 2

# %%
aluno = { 'Adriana' : { 'P1' : 10 } }
type(aluno)

# Um dicionário contendo um dicionário. C
# Out:
# dict

# %% [markdown]
# ## Questão 3
#
# i. Não
#
# ii. Sim, com certeza
#
# iii. Não
#
# Alternativa: C.

# %% [markdown]
# ## Questão 4

# %%
mpg = pd.read_excel('questao4.xlsx')
mpg
# Out:
#    mpg  cylinders  displacement  horsepower  weight  accelaration  model_year  \
# 0   18          8           307         130    3504          12.0          70
# 1   15          8           350         165    3693          11.5          70
# 2   18          8           318         150    3436          11.0          70
# 3   16          8           304         150    3433          12.0          70
# 4   17          8           302         140    3449          10.5          70
# 5   17          8           302         140    3449          10.5          70
# 6   17          8           302         140    3449          10.5          70
# 7   17          8           302         140    3449          10.5          70
#
#      origin           name
# 0       usa      modelo um
# 1       usa    modelo dois
# 2       usa    modelo tres
# 3       usa  modelo quatro
# 4       usa   modelo cinco
# 5    brasil   modelo cinco
# 6    brasil   modelo cinco
# 7  alemanha   modelo cinco

# %%
print(mpg.origin.value_counts())
# Out:
# usa         5
# brasil      2
# alemanha    1
# Name: origin, dtype: int64

# %%
print(mpg.groupby('origin').origin.count())
# Out:
# origin
# alemanha    1
# brasil      2
# usa         5
# Name: origin, dtype: int64

# %%
print(mpg.origin.count())
# Out:
# 8

# %% [markdown]
# i. Sim
#
# ii. Sim
#
# iii. Não
#
# Alternativa: A.

# %% [markdown]
# ## Questão 5 (?)
#
# Identificar os países mais consumidores de café e a participação da empresa dentro desses países visando identificar os mercados onde ela ainda teria espaço para atuar.
#
# Alternativa: E.

# %% [markdown]
# ## Questão 6

# %%
mpg = pd.read_excel('questao4.xlsx')
mpg
# Out:
#    mpg  cylinders  displacement  horsepower  weight  accelaration  model_year  \
# 0   18          8           307         130    3504          12.0          70
# 1   15          8           350         165    3693          11.5          70
# 2   18          8           318         150    3436          11.0          70
# 3   16          8           304         150    3433          12.0          70
# 4   17          8           302         140    3449          10.5          70
# 5   20          8           302         140    3449          10.5          70
# 6   22          8           302         140    3449          10.5          70
# 7   25          8           302         140    3449          10.5          70
# 8   24          8           302         140    3449          10.5          70
#
#    origin           name
# 0     usa      modelo um
# 1     usa    modelo dois
# 2     usa    modelo tres
# 3     usa  modelo quatro
# 4     usa   modelo cinco
# 5   japao   modelo cinco
# ...

# %%
import seaborn as sns

# %%
sns.boxplot(mpg.mpg,mpg.origin)
# Out:
# c:\users\guisa\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %%
sns.lineplot(mpg.mpg,mpg.origin)
# Out:
# c:\users\guisa\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %%
sns.distplot(mpg.mpg,mpg.origin)

# %%
sns.histplot(mpg.mpg, mpg.origin)

# %%
sns.scatterplot(mpg.mpg, mpg.origin)
# Out:
# c:\users\guisa\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %% [markdown]
# Alternativa. A.

# %% [markdown]
# ## Questão 7
#
# Alternativa: E.

# %% [markdown]
# ## Questão 8
#
# i. Não
#
# ii. Não
#
# iii. Sim
#
# Alternativa: D.
