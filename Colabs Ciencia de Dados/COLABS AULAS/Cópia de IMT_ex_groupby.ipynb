# %% [markdown]
# <head>
#   <meta name="author" content="Rogério de Oliveira">
#   <meta institution="author" content="ITM">
# </head>
#
# <img src="https://maua.br/images/selo-60-anos-maua.svg" width=300, align="right">
# <!-- <h1 align=left><font size = 6, style="color:rgb(200,0,0)"> optional title </font></h1> -->

# %% [markdown]
# # Lab: Rename, drop, replace, concat, groupby
#
# Referências e Materiais úteis para este Lab:
#
# - [Notas de Aula](https://colab.research.google.com/github/Rogerio-mack/IMT_Ciencia_de_Dados/blob/main/IMT_Pandas_I.ipynb)
# - [Pandas User Guide](https://pandas.pydata.org/docs/user_guide/index.html#user-guide)
# - [Groupby](https://pandas.pydata.org/docs/user_guide/groupby.html)
# ---

# %%
import numpy as np
import pandas as pd

path = 'https://github.com/Rogerio-mack/IMT_Ciencia_de_Dados/raw/main/data/'

# %% [markdown]
# ## Q0. `rename()`,`drop()`,`replace()`,`concat()`
#
# Combine os dados a seguir em novo DataFrame `company` incorporando as contratações dos meses de FEV e MAR que não constam do DataFrame `company_before`.
#
# Considere que:
# 1. A companhia passará a usar um novo `id` para os empregados e, portanto, esse dado não precisa constar do novo DataFrame `company`.
# 2. No mês de março devido a problemas com mudanças na companhia os dados das contratações encontram-se em um layout diferente (nome e ordem dos atributos) e foram usados alguns valores categóricos diferentes nos atributos.

# %%
company_before = pd.read_csv(path + 'company_before.csv')
company_fev = pd.read_csv(path + 'company_fev.csv')
company_mar = pd.read_csv(path + 'company_mar.csv')

display(company_before)
display(company_fev)
display(company_mar)
# Out:
#         id           Setor       Sexo       Grau_Instrucao  Idade  \
# 0        1        Operacao  Masculino    Superior Completo     54
# 1        2              RH  Masculino            Doutorado     52
# 2        3              RH  Masculino             Mestrado     54
# 3        4      Financeiro   Feminino             Mestrado     32
# 4        5              RH  Masculino  Superior Incompleto     34
# ...    ...             ...        ...                  ...    ...
# 1490  1516  Administrativo   Feminino  Superior Incompleto     39
# 1491  1517              RH  Masculino    Superior Completo     34
# 1492  1518        Operacao  Masculino    Superior Completo     37
# 1493  1519        Operacao   Feminino    Superior Completo     57
# 1494  1520              RH   Feminino    Superior Completo     46
#
#       Anos_Experiencia Estado      Salario
# 0                   12     SP  2708.410161
# 1                   12     SP  8321.204000
# 2                   12     RJ  7588.139000
# 3                    9     BH  6512.599657
# 4                    8     BH  3125.765000
# ...                ...    ...          ...
# 1490                15     BH  2171.749259
# 1491                 8     SP  6603.683000
# 1492                13     SP  4479.974250
# 1493                10     BH  6923.622400
# 1494                15     SP  5359.789000
#
# [1495 rows x 8 columns]
#      id           Setor       Sexo       Grau_Instrucao  Idade  \
# 0  1390  Administrativo   Feminino  Superior Incompleto     55
# 1  1407       Marketing  Masculino    Superior Completo     40
# 2  1347  Administrativo   Feminino             Mestrado     35
# 3  1123        Operacao  Masculino             Mestrado     45
# 4  1042  Administrativo   Feminino  Superior Incompleto     43
# 5   107      Financeiro  Masculino    Superior Completo     54
# 6  1148       Marketing  Masculino    Superior Completo     61
# 7  1239  Administrativo  Masculino            Doutorado     72
# 8    97       Marketing   Feminino    Superior Completo     47
# 9   114        Operacao   Feminino    Superior Completo     52
#
#    Anos_Experiencia Estado       Salario
# 0                11     SP   1999.616745
# 1                17     SP   5139.437521
# 2                 8     SP   6883.379725
# 3                16     SP   6386.825060
# 4                16     BH   1877.931320
# 5                12     BH   3725.828517
# 6                 9     BH   6182.349859
# 7                 7     SP  15371.570000
# 8                15     SP   6137.674634
# 9                13     SP   1960.454000
#    Sex       Grau_Instrucao  Experiencia  Idade Estado       Salario  \
# 0    M    Superior Completo           11     56     SP   3722.984809
# 1    F    Superior Completo            9     31     RJ  10290.856780
# 2    F  Superior Incompleto           12     53     SP   3583.467000
# 3    M            Doutorado           16     45     BH  10588.027760
# 4    F  Superior Incompleto           15     46     SP   1995.308000
# 5    M    Superior Completo           17     41     SP   2182.034262
# 6    M    Superior Completo           13     51     SP   8980.024053
# 7    F  Superior Incompleto           16     43     RJ   5877.276943
# 8    M    Superior Completo           10     58     BH   6538.568000
# 9    M    Superior Completo           16     44     RJ   2625.620436
# 10   M    Superior Completo            8     35     SP   4087.606289
# 11   M             Mestrado           14     50     SP   6294.245630
# 12   M    Superior Completo            8     63     SP   2769.916194
# 13   M    Superior Completo            9     61     SP   4275.077705
# 14   F            Doutorado            8     36     SP  10748.475840
#
#         Departamento
# 0           Operacao
# 1     Administrativo
# 2   Recursos Humanos
# 3           Operacao
# 4     Administrativo
# 5         Financeiro
# 6           Operacao
# 7           Operacao
# 8   Recursos Humanos
# 9           Operacao
# 10         Marketing
# 11         Marketing
# 12    Administrativo
# 13    Administrativo
# 14        Financeiro

# %% [markdown]
# Dica: Veja a seguir instruções úteis neste exercício.

# %%
df = pd.DataFrame({ '123': [1,2,3], 'BBB': ['b','b','c'], 'X':['a','b','c'], 'delete':[None, None, None]})
df
# Out:
#    123 BBB  X delete
# 0    1   b  a   None
# 1    2   b  b   None
# 2    3   c  c   None

# %%
df = df.drop(columns=['delete'])
# df.drop(columns=['delete'],inplace=True)
df
# Out:
#    123 BBB  X
# 0    1   b  a
# 1    2   b  b
# 2    3   c  c

# %%
df = df.rename(columns={'X':'ABC'})
# df.rename(columns={'X':'ABC'},inplace=True)
df
# Out:
#    123 BBB ABC
# 0    1   b   a
# 1    2   b   b
# 2    3   c   c

# %%
df.BBB.unique()
# Out:
# array(['b', 'c'], dtype=object)

# %%
df.BBB = df.BBB.replace('c','b')
df
# Out:
#    123 BBB ABC
# 0    1   b   a
# 1    2   b   b
# 2    3   b   c

# %% [markdown]
# 1. Exclua o `id` de `company_before` e `company_fev`.

# %%
# Seu código
company_before = company_before.drop(columns=['id'])
company_fev = company_fev.drop(columns=['id'])

# %% [markdown]
# 2. Ajuste o nome das colunas no DataFrame `company_mar`.

# %%
# Seu código
company_mar = company_mar.rename(columns={'Sex': 'Sexo', 'Experiencia': 'Anos_Experiencia', 'Departamento': 'Setor'})

# %% [markdown]
# 3. Ajuste a ordem das colunas em `company_mar`.

# %%
# Seu código
company_mar = company_mar.reindex(columns=['Setor', 'Sexo', 'Grau_Instrucao', 'Idade', 'Anos_Experiencia', 'Estado', 'Salario'])

# %% [markdown]
# 4. Verifique e ajuste os valores dos rótulos empregados nos campos `object` (strings) de `company_mar`

# %%
# Seu código
company_mar = company_mar.replace({'Sexo': ['M','F'], 'Setor': 'Recursos Humanos'}, {'Sexo': ['Masculino', 'Feminino'], 'Setor': 'RH'})
company_mar.head()
# Out:
#             Setor       Sexo       Grau_Instrucao  Idade  Anos_Experiencia  \
# 0        Operacao  Masculino    Superior Completo     56                11
# 1  Administrativo   Feminino    Superior Completo     31                 9
# 2              RH   Feminino  Superior Incompleto     53                12
# 3        Operacao  Masculino            Doutorado     45                16
# 4  Administrativo   Feminino  Superior Incompleto     46                15
#
#   Estado       Salario
# 0     SP   3722.984809
# 1     RJ  10290.856780
# 2     SP   3583.467000
# 3     BH  10588.027760
# 4     SP   1995.308000

# %% [markdown]
# 5. Concatene os DataFrames em um único DataFrame `company`.

# %%
# Seu código
company = pd.concat([company_before, company_fev])
company = pd.concat([company, company_mar])
company
# Out:
#              Setor       Sexo       Grau_Instrucao  Idade  Anos_Experiencia  \
# 0         Operacao  Masculino    Superior Completo     54                12
# 1               RH  Masculino            Doutorado     52                12
# 2               RH  Masculino             Mestrado     54                12
# 3       Financeiro   Feminino             Mestrado     32                 9
# 4               RH  Masculino  Superior Incompleto     34                 8
# ..             ...        ...                  ...    ...               ...
# 10       Marketing  Masculino    Superior Completo     35                 8
# 11       Marketing  Masculino             Mestrado     50                14
# 12  Administrativo  Masculino    Superior Completo     63                 8
# 13  Administrativo  Masculino    Superior Completo     61                 9
# 14      Financeiro   Feminino            Doutorado     36                 8
#
#    Estado       Salario
# 0      SP   2708.410161
# 1      SP   8321.204000
# 2      RJ   7588.139000
# 3      BH   6512.599657
# 4      BH   3125.765000
# ..    ...           ...
# 10     SP   4087.606289
# 11     SP   6294.245630
# 12     SP   2769.916194
# 13     SP   4275.077705
# 14     SP  10748.475840
#
# [1520 rows x 7 columns]

# %%
#@markdown Must be True
len(company) == 1520
# Out:
# True

# %% [markdown]
# (Moodle) Qual a soma dos salários, o maior salário, e de qual departamento, depois de os dados da companhia terem sido atualizados?

# %%
# Seu código
display(company['Salario'].sum())
display(company[['Salario','Setor']].nlargest(n = 1, columns='Salario'))
display()
# Out:
# 8705724.860367
#        Salario           Setor
# 1402  19790.41  Administrativo

# %% [markdown]
# ## Q1. `groupby()`, `get_group()`
#
# Empregue os comandos `groupby()` e `get_group()` para criar um DataFrame para cada `Setor`, apenas com seus dados próprios. Salve cada DataFrame em um Arquivo no formato `.csv` e outro no formato `.json`. Cada DataFrame terá o nome do setor (`setor.csv` e `setor.json`) e apenas as colunas:
#
# ```
# ['Sexo', 'Grau_instrucao', 'Idade', 'Anos_Experiencia', 'Estado', 'Salario']
# ```
# (sem `Setor`!). Em seguida, empregue o comando `memory_usage()` e obtenha a memória usada por cada DataFrame (`.csv`).

# %% [markdown]
# Um exemplo do DataFrame `Administrativo` a ser criado:

# %%
#@markdown 

# Atenção esta não é a solução, é apenas para fornecer o aspecto da saída esperada 

temp = company[ company.Setor == 'Administrativo' ].head(5).drop(columns='Setor').reset_index(drop=True).head()

print('DataFrame: Admistrativo')
display( temp.head() )
print()
print( f'memory usage: {temp.memory_usage().sum() / 1024:.1f}KB' )
# Out:
# DataFrame: Admistrativo
#         Sexo     Grau_Instrucao  Idade  Anos_Experiencia Estado      Salario
# 0  Masculino           Mestrado     32                 9     SP  6948.868398
# 1  Masculino  Superior Completo     47                15     RJ  8687.786858
# 2  Masculino  Superior Completo     47                15     SP  7914.972759
# 3  Masculino  Superior Completo     56                11     SP  5595.857117
# 4  Masculino           Mestrado     32                 9     BH  6802.579902
# memory usage: 0.4KB

# %% [markdown]
# Dica: Veja o exemplo a seguir de como empregar o `get_group()`.

# %%
#@markdown
df = pd.DataFrame(
    [
        ("bird", "Falconiformes", 389.0),
        ("bird", "Psittaciformes", 24.0),
        ("mammal", "Carnivora", 80.2),
        ("mammal", "Primates", np.nan),
        ("mammal", "Carnivora", 58),
    ],
    index=["falcon", "parrot", "lion", "monkey", "leopard"],
    columns=("class", "order", "max_speed"),
)

df
# Out:
#           class           order  max_speed
# falcon     bird   Falconiformes      389.0
# parrot     bird  Psittaciformes       24.0
# lion     mammal       Carnivora       80.2
# monkey   mammal        Primates        NaN
# leopard  mammal       Carnivora       58.0

# %%
g = df.groupby('class')

# %%
g.groups.keys()
# Out:
# dict_keys(['bird', 'mammal'])

# %%
g.get_group('bird')
# Out:
#        class           order  max_speed
# falcon  bird   Falconiformes      389.0
# parrot  bird  Psittaciformes       24.0

# %%
g = company.groupby('Setor')
dfs_setores = []
# Seu código
for setor in g:
  setor_r = {}
  setor_r['Setor'] = setor[0]
  temp = setor[1].drop(columns='Setor').reset_index(drop=True)
  print(f"DataFrame: {setor[0]}")
  print( f'memory usage: {temp.memory_usage().sum() / 1024:.1f}KB' )
  #display(temp)
  setor_r['df'] = temp
  dfs_setores.append(setor_r)
  temp.to_csv(f'{setor[0]}.csv')
  temp.to_json(f'{setor[0]}.json')
# Out:
# DataFrame: Administrativo
# memory usage: 19.0KB
# DataFrame: Financeiro
# memory usage: 8.5KB
# DataFrame: Marketing
# memory usage: 9.1KB
# DataFrame: Operacao
# memory usage: 26.2KB
# DataFrame: RH
# memory usage: 9.0KB

# %%
display(dfs_setores)
# Out:
# [{'Setor': 'Administrativo',
#   'df':           Sexo       Grau_Instrucao  Idade  Anos_Experiencia Estado  \
#   0    Masculino             Mestrado     32                 9     SP
#   1    Masculino    Superior Completo     47                15     RJ
#   2    Masculino    Superior Completo     47                15     SP
#   3    Masculino    Superior Completo     56                11     SP
#   4    Masculino             Mestrado     32                 9     BH
#   ..         ...                  ...    ...               ...    ...
#   398  Masculino            Doutorado     72                 7     SP
#   399   Feminino    Superior Completo     31                 9     RJ
#   400   Feminino  Superior Incompleto     46                15     SP
#   401  Masculino    Superior Completo     63                 8     SP
#   402  Masculino    Superior Completo     61                 9     SP
#
#             Salario
#   0     6948.868398
#   1     8687.786858
#   2     7914.972759
#   3     5595.857117
#   4     6802.579902
#   ..            ...
#   398  15371.570000
#   399  10290.856780
#   400   1995.308000
#   401   2769.916194
#   402   4275.077705
#
#   [403 rows x 6 columns]},
#  {'Setor': 'Financeiro',
#   'df':           Sexo       Grau_Instrucao  Idade  Anos_Experiencia Estado  \
#   0     Feminino             Mestrado     32                 9     BH
#   1    Masculino    Superior Completo     65                 8     SP
#   2     Feminino  Superior Incompleto     63                 8     SP
#   3    Masculino    Superior Completo     47                15     BH
#   4    Masculino            Doutorado     55                 8     SP
#   ..         ...                  ...    ...               ...    ...
#   174   Feminino  Superior Incompleto     50                13     SP
#   175   Feminino  Superior Incompleto     66                 7     SP
#   176  Masculino    Superior Completo     54                12     BH
#   177  Masculino    Superior Completo     41                17     SP
#   178   Feminino            Doutorado     36                 8     SP
#
#             Salario
#   0     6512.599657
#   1     2024.994882
#   2     2038.753298
#   3     2818.107045
#   4     9553.051933
#   ..            ...
#   174   2027.150338
#   175   2028.074029
#   176   3725.828517
#   177   2182.034262
#   178  10748.475840
#
#   [179 rows x 6 columns]},
#  {'Setor': 'Marketing',
#   'df':           Sexo       Grau_Instrucao  Idade  Anos_Experiencia Estado  \
#   0    Masculino    Superior Completo     31                 9     SP
#   1    Masculino  Superior Incompleto     40                17     SP
#   2     Feminino  Superior Incompleto     37                13     RJ
#   3     Feminino    Superior Completo     47                15     BH
#   4     Feminino    Superior Completo     52                13     SP
#   ..         ...                  ...    ...               ...    ...
#   187  Masculino    Superior Completo     40                17     SP
#   188  Masculino    Superior Completo     61                 9     BH
#   189   Feminino    Superior Completo     47                15     SP
#   190  Masculino    Superior Completo     35                 8     SP
#   191  Masculino             Mestrado     50                14     SP
#
#            Salario
#   0    6275.597489
#   1    2104.902227
#   2    2014.408523
#   3    7990.101936
#   4    4418.462731
#   ..           ...
#   187  5139.437521
#   188  6182.349859
#   189  6137.674634
#   190  4087.606289
#   191  6294.245630
#
#   [192 rows x 6 columns]},
#  {'Setor': 'Operacao',
#   'df':           Sexo       Grau_Instrucao  Idade  Anos_Experiencia Estado  \
#   0    Masculino    Superior Completo     54                12     SP
#   1    Masculino    Superior Completo     52                13     BH
#   2     Feminino    Superior Completo     38                12     SP
#   3    Masculino             Mestrado     45                16     SP
#   4    Masculino  Superior Incompleto     40                17     SP
#   ..         ...                  ...    ...               ...    ...
#   552  Masculino    Superior Completo     56                11     SP
#   553  Masculino            Doutorado     45                16     BH
#   554  Masculino    Superior Completo     51                13     SP
#   555   Feminino  Superior Incompleto     43                16     RJ
#   556  Masculino    Superior Completo     44                16     RJ
#
#             Salario
#   0     2708.410161
#   1     1368.040623
#   2    10497.986350
#   3     6488.446200
#   4     5674.497590
#   ..            ...
#   552   3722.984809
#   553  10588.027760
#   554   8980.024053
#   555   5877.276943
#   556   2625.620436
#
#   [557 rows x 6 columns]},
#  {'Setor': 'RH',
#   'df':           Sexo       Grau_Instrucao  Idade  Anos_Experiencia Estado   Salario
#   0    Masculino            Doutorado     52                12     SP  8321.204
#   1    Masculino             Mestrado     54                12     RJ  7588.139
#   2    Masculino  Superior Incompleto     34                 8     BH  3125.765
#   3     Feminino             Mestrado     66                 8     RJ  7878.497
#   4     Feminino    Superior Completo     68                 7     SP  6815.129
#   ..         ...                  ...    ...               ...    ...       ...
#   184  Masculino  Superior Incompleto     28                 5     SP  3046.940
#   185  Masculino    Superior Completo     34                 8     SP  6603.683
#   186   Feminino    Superior Completo     46                15     SP  5359.789
#   187   Feminino  Superior Incompleto     53                12     SP  3583.467
#   188  Masculino    Superior Completo     58                10     BH  6538.568
#
#   [189 rows x 6 columns]}]

# %% [markdown]
# (Moodle) Qual a memória ocupada pelos DataFrames `Administrativo` e `Financeiro` criados?

# %% [markdown]
# ## Q2. `to_json`
#
# (Moodle) Inspecione o DataFrame `json` criado. É o que você esperava encontrar? O que melhor descreve o formato encontrado? Verifique em https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_json.html. The format of the JSON string.
# ```
# ( ) ‘split’
# ( ) ‘records’
# ( ) ‘index’
# ( ) ‘columns’
# ( ) ‘values’
# ( ) ‘table’
# ```

# %%
# !cat Administrativo.json
# Out:
# {"Sexo":{"0":"Masculino","1":"Masculino","2":"Masculino","3":"Masculino","4":"Masculino","5":"Masculino","6":"Masculino","7":"Masculino","8":"Masculino","9":"Masculino","10":"Masculino","11":"Feminino","12":"Feminino","13":"Masculino","14":"Masculino","15":"Masculino","16":"Masculino","17":"Masculino","18":"Feminino","19":"Feminino","20":"Masculino","21":"Masculino","22":"Masculino","23":"Feminino","24":"Masculino","25":"Feminino","26":"Masculino","27":"Masculino","28":"Feminino","29":"Masculino","30":"Masculino","31":"Masculino","32":"Feminino","33":"Masculino","34":"Masculino","35":"Masculino","36":"Masculino","37":"Masculino","38":"Feminino","39":"Feminino","40":"Masculino","41":"Masculino","42":"Feminino","43":"Feminino","44":"Feminino","45":"Masculino","46":"Masculino","47":"Masculino","48":"Masculino","49":"Masculino","50":"Masculino","51":"Masculino","52":"Masculino","53":"Masculino","54":"Masculino","55":"Masculino","56":"Masculino","57":"Masculino","58":"Masculino","59":"Masculino","60":"Masculino","61":"Masculino","62":"Feminino","63":"Masculino","64":"Feminino","65":"Feminino","66":"Masculino","67":"Masculino","68":"Feminino","69":"Masculino","70":"Masculino","71":"Masculino","72":"Masculino","73":"Masculino","74":"Feminino","75":"Masculino","76":"Masculino","77":"Feminino","78":"Feminino","79":"Masculino","80":"Masculino","81":"Feminino","82":"Feminino","83":"Masculino","84":"Masculino","85":"Masculino","86":"Feminino","87":"Feminino","88":"Feminino","89":"Masculino","90":"Feminino","91":"Masculino","92":"Feminino","93":"Masculino","94":"Masculino","95":"Masculino","96":"Masculino","97":"Feminino","98":"Masculino","99":"Feminino","100":"Feminino","101":"Masculino","102":"Feminino","103":"Feminino","104":"Masculino","105":"Masculino","106":"Masculino","107":"Feminino","108":"Feminino","109":"Feminino","110":"Feminino","111":"Masculino","112":"Feminino","113":"Masculino","114":"Feminino","115":"Feminino","116":"Masculino","117":"Feminino","118":"Masculino","119":"Masculino","120":"Feminino","121":"Feminino","122":"Feminino","123":"Feminino","124":"Masculino","125":"Masculino","126":"Masculino","127":"Masculino","128":"Masculino","129":"Masculino","130":"Masculino","131":"Feminino","132":"Feminino","133":"Masculino","134":"Masculino","135":"Feminino","136":"Masculino","137":"Feminino","138":"Feminino","139":"Feminino","140":"Feminino","141":"Masculino","142":"Feminino","143":"Masculino","144":"Masculino","145":"Feminino","146":"Feminino","147":"Feminino","148":"Masculino","149":"Masculino","150":"Masculino","151":"Feminino","152":"Masculino","153":"Feminino","154":"Feminino","155":"Masculino","156":"Masculino","157":"Masculino","158":"Masculino","159":"Feminino","160":"Masculino","161":"Feminino","162":"Masculino","163":"Feminino","164":"Masculino","165":"Feminino","166":"Masculino","167":"Masculino","168":"Feminino","169":"Masculino","170":"Feminino","171":"Masculino","172":"Masculino","173":"Masculino","174":"Feminino","175":"Masculino","176":"Feminino","177":"Feminino","178":"Feminino","179":"Masculino","180":"Masculino","181":"Masculino","182":"Masculino","183":"Masculino","184":"Masculino","185":"Feminino","186":"Feminino","187":"Masculino","188":"Feminino","189":"Masculino","190":"Masculino","191":"Feminino","192":"Masculino","193":"Feminino","194":"Masculino","195":"Feminino","196":"Masculino","197":"Masculino","198":"Feminino","199":"Masculino","200":"Feminino","201":"Feminino","202":"Feminino","203":"Masculino","204":"Masculino","205":"Masculino","206":"Masculino","207":"Feminino","208":"Feminino","209":"Masculino","210":"Masculino","211":"Masculino","212":"Masculino","213":"Feminino","214":"Feminino","215":"Masculino","216":"Masculino","217":"Masculino","218":"Masculino","219":"Masculino","220":"Feminino","221":"Masculino","222":"Masculino","223":"Masculino","224":"Feminino","225":"Masculino","226":"Masculino","227":"Masculino","228":"Masculino","229":"Feminino","230":"Feminino","231":"Feminino","232":"Mascu ...

# %% [markdown]
# ## Q3. `agg()`, `mode()`
#
# Veja os exemplos abaixo de como empregar a função `agg()` e como criar uma função nova para uso dentro do `agg()`.

# %%
df
# Out:
#           class           order  max_speed
# falcon     bird   Falconiformes      389.0
# parrot     bird  Psittaciformes       24.0
# lion     mammal       Carnivora       80.2
# monkey   mammal        Primates        NaN
# leopard  mammal       Carnivora       58.0

# %%
def my_mode(x): # x.mode() é um método que tornamos aqui como uma função para poder ser empregada com agg()
  return x.mode()

# %%
my_mode(df['order'])
# Out:
# 0    Carnivora
# Name: order, dtype: object

# %%
df.groupby('class')['order'].agg(my_mode)
# Out:
# class
# bird      [Falconiformes, Psittaciformes]
# mammal                          Carnivora
# Name: order, dtype: object

# %%
import numpy as np

df.groupby('class')[['order','max_speed']].agg({'order': my_mode, 'max_speed': np.mean})
# Out:
#                                   order  max_speed
# class
# bird    [Falconiformes, Psittaciformes]      206.5
# mammal                        Carnivora       69.1

# %% [markdown]
# Empregue os exemplos para fornecer os valores de moda (atributos categóricos) e médios (atributos numéricos) para todos os valores de `company` por Setor.

# %%
# Seu código
company.groupby('Setor')[company.columns].agg({'Setor': my_mode,'Sexo': my_mode, 'Grau_Instrucao': my_mode, 'Idade': np.mean, 'Anos_Experiencia': np.mean, 'Estado': my_mode, 'Salario': np.mean})
# Out:
#                          Setor       Sexo     Grau_Instrucao      Idade  \
# Setor
# Administrativo  Administrativo  Masculino  Superior Completo  49.833747
# Financeiro          Financeiro  Masculino  Superior Completo  50.379888
# Marketing            Marketing  Masculino  Superior Completo  48.541667
# Operacao              Operacao  Masculino  Superior Completo  49.120287
# RH                          RH  Masculino  Superior Completo  50.481481
#
#                 Anos_Experiencia Estado      Salario
# Setor
# Administrativo         11.444169     SP  5579.490246
# Financeiro             11.592179     SP  5009.500543
# Marketing              11.359375     SP  5035.949557
# Operacao               11.204668     SP  6364.649269
# RH                     11.174603     SP  5547.501249

# %% [markdown]
# (Moodle) Há algum Setor onde os valores de moda diferem dos demais? Se sim, qual a média de Salário desse Setor?

# %% [markdown]
# ## Q4. `map()`
#
# Empregue `map()` para criar um atributo `Codigo_instrucao` atribuindo valores inteiros $1$ a $n$ do menor para o maior `Grau_Instrucao` (ordem alfabética).

# %%
# Seu código
lista_grau = list(pd.unique(company['Grau_Instrucao']))
lista_grau.sort()
print(lista_grau)

mapa = {}
n = 1
for item in lista_grau:
  mapa[f'{item}'] = n
  n += 1
print(mapa)

company['Codigo_instrucao'] = company['Grau_Instrucao'].map(mapa)
display(company)
# Out:
# ['Doutorado', 'Mestrado', 'Superior Completo', 'Superior Incompleto']
# {'Doutorado': 1, 'Mestrado': 2, 'Superior Completo': 3, 'Superior Incompleto': 4}
#              Setor       Sexo       Grau_Instrucao  Idade  Anos_Experiencia  \
# 0         Operacao  Masculino    Superior Completo     54                12
# 1               RH  Masculino            Doutorado     52                12
# 2               RH  Masculino             Mestrado     54                12
# 3       Financeiro   Feminino             Mestrado     32                 9
# 4               RH  Masculino  Superior Incompleto     34                 8
# ..             ...        ...                  ...    ...               ...
# 10       Marketing  Masculino    Superior Completo     35                 8
# 11       Marketing  Masculino             Mestrado     50                14
# 12  Administrativo  Masculino    Superior Completo     63                 8
# 13  Administrativo  Masculino    Superior Completo     61                 9
# 14      Financeiro   Feminino            Doutorado     36                 8
#
#    Estado       Salario  Codigo_instrucao
# 0      SP   2708.410161                 3
# 1      SP   8321.204000                 1
# 2      RJ   7588.139000                 2
# 3      BH   6512.599657                 2
# 4      BH   3125.765000                 4
# ..    ...           ...               ...
# 10     SP   4087.606289                 3
# 11     SP   6294.245630                 2
# 12     SP   2769.916194                 3
# 13     SP   4275.077705                 3
# 14     SP  10748.475840                 1
#
# [1520 rows x 8 columns]

# %% [markdown]
# (Moodle) Fazendo o valor de soma dos valores do novo atributo Codigo_Instrucao?

# %%
# Seu código
company['Codigo_instrucao'].sum()
# Out:
# 4498

# %% [markdown]
# ## Q5. Tabela de contingência, `pd.crosstab()`
#
# Pesquise `pd.crosstab()` e o que é uma tabela de contigência. Em seguida construa uma tabela de contigência para responder a seguinte pergunta.

# %% [markdown]
# (Moodle) Qual Setor possui menos mulheres trabalhando e qual o percentual que essas mulheres representam de toda a companhia?

# %%
# Seu código
f = company[company['Sexo'] == 'Feminino'].groupby('Setor')
f.count()
#66/1520
# Out:
#                 Sexo  Grau_Instrucao  Idade  Anos_Experiencia  Estado  \
# Setor
# Administrativo   163             163    163               163     163
# Financeiro        72              72     72                72      72
# Marketing         66              66     66                66      66
# Operacao         221             221    221               221     221
# RH                72              72     72                72      72
#
#                 Salario  Codigo_instrucao
# Setor
# Administrativo      163               163
# Financeiro           72                72
# Marketing            66                66
# Operacao            221               221
# RH                   72                72

# %% [markdown]
# O `crosstab`, entretando, é limitado a índices simples.Tabelas semelhantes com índices múltiplos podem ser obtidas combinando-se `groupby()` com `.unstack()`.

# %%
( company.groupby(["Sexo","Setor","Grau_Instrucao"])[["Salario"]].count().unstack() / len(company) ) # .sum().sum()
# Out:
#                            Salario                              \
# Grau_Instrucao           Doutorado  Mestrado Superior Completo
# Sexo      Setor
# Feminino  Administrativo  0.010526  0.014474          0.051974
#           Financeiro      0.001974  0.006579          0.022368
#           Marketing       0.002632  0.003947          0.021711
#           Operacao        0.013158  0.019079          0.079605
#           RH              0.001974  0.003289          0.026316
# Masculino Administrativo  0.009868  0.030921          0.080921
#           Financeiro      0.005921  0.009868          0.038158
#           Marketing       0.005921  0.013158          0.046711
#           Operacao        0.019079  0.033553          0.113158
#           RH              0.005921  0.013158          0.032895
#
#
# Grau_Instrucao           Superior Incompleto
# Sexo      Setor
# Feminino  Administrativo            0.030263
#           Financeiro                0.016447
#           Marketing                 0.015132
#           Operacao                  0.033553
#           RH                        0.015789
# Masculino Administrativo            0.036184
#           Financeiro                0.016447
#           Marketing                 0.017105
#           Operacao                  0.055263
#           RH                        0.025000
